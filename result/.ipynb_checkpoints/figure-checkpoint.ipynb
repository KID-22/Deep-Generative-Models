# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
# %config InlineBackend.figure_format = 'svg' # 画矢量图
plt.rcParams['font.sans-serif']=['Times New Roman'] # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False # 用来正常显示负号

# %%
del matplotlib.font_manager.weight_dict['roman']
matplotlib.font_manager._rebuild()

# %%
pos_skip_rate_10 = [0.12258604834471887,
 0.10665347007730243,
 0.10662616756794718,
 0.10614706001375905,
 0.10380544922314794,
 0.09671442687747035,
 0.09552882025498294,
 0.09619188921859545,
 0.08257772020725389,
 0.0852803738317757,
 0.08255597014925373,
 0.08342361863488625,
 0.08284789644012945,
 0.07686084142394822,
 0.07613741875580315,
 0.07752808988764046,
 0.07731958762886598,
 0.05255023183925812,
 0.05152671755725191,
 0.05442176870748299]

# %%
x = np.arange(0,10)

plt.figure(1,figsize=(7.5,3.5)) 
total_width, n = 0.5, 1
width = total_width / n
x = x - (total_width - width) / 1

plt.bar(x, pos_skip_rate_10[:10], width=width, color = "cornflowerblue")
plt.xticks(np.arange(0,10), [str(i*10+1)+"-"+str((i+1)*10) for i in range(0,10)],size='small',fontsize=15)
plt.yticks(size='small',fontsize=15)
plt.ylim(0.07,0.13)
# plt.yticks(np.arange(0.09,0.13,0.01))
plt.ylabel("Percentage of User's Skip Events",fontsize=16)
plt.xlabel("Position in Session",fontsize=16)

plt.tight_layout() #去除pdf周围白边
plt.savefig('./fig/skip_position.pdf', format='pdf',bbox_inches='tight', dpi=800)
plt.show()

# %%
SBUCB = [0.780875,0.785975,0.784625,0.7833875,0.7826625,0.78225]


x = np.arange(0,6)

plt.figure(1,figsize=(7.5,3.3)) 
total_width, n = 0.45, 1
width = total_width / n
x = x - (total_width - width) / 1

plt.bar(x, SBUCB, width=width, color = "pink")
plt.xticks(np.arange(0,6), ["original", "2", "4", "6", "8", "10"],size='small',fontsize=15)
plt.yticks(size='small',fontsize=15)
plt.ylim(0.779,0.787)
# plt.yticks(np.arange(0.09,0.13,0.01))
plt.ylabel("OnlineAverageReward@800",fontsize=16)
plt.xlabel("# of Cutoff",fontsize=16)

plt.tight_layout() #去除pdf周围白边
plt.savefig('./fig/sbucbcutoff.pdf', format='pdf',bbox_inches='tight', dpi=800)
plt.show()

# %%
x = np.arange(0,10)

plt.figure(1,figsize=(6.5,3.5)) 
total_width, n = 0.5, 1
width = total_width / n
x = x - (total_width - width) / 1

plt.bar(x, pos_skip_rate_10[:10], width=width, color = "cornflowerblue", alpha=0.7)
plt.xticks(np.arange(0,10), [str(i*10+1)+"-"+str((i+1)*10) for i in range(0,10)],size='small',fontsize=13)
plt.yticks(size='small',fontsize=13)
plt.ylim(0.07,0.13)
# plt.yticks(np.arange(0.09,0.13,0.01))
plt.ylabel("Percentage of User's Skip Events",fontsize=15)
plt.xlabel("Position in Session",fontsize=15)

plt.tight_layout() #去除pdf周围白边
plt.savefig('./fig/skip_position-1.pdf', format='pdf',bbox_inches='tight', dpi=800)
plt.show()

# %%
SBUCB = [0.780875,0.785975,0.784625,0.7833875,0.7826625,0.78225]
SBUCB.reverse()
label = ["∞", "2", "4", "6", "8", "10"]
label.reverse()

x = np.arange(0,6)

plt.figure(1,figsize=(3.8,3.5)) 
total_width, n = 0.45, 1
# width = total_width / n
# x = x - (total_width - width) / 1

plt.barh(x, SBUCB, height=0.45, color='pink', alpha=0.7)
plt.yticks(np.arange(0,6),label ,size='small',fontsize=13)
plt.xticks(size='small',fontsize=13)
plt.xlim(0.779,0.787)
# plt.yticks(np.arange(0.09,0.13,0.01))
plt.xlabel("OnlineAverageReward@800",fontsize=15)
plt.ylabel("#  of  Cutoff",fontsize=15)

plt.tight_layout() #去除pdf周围白边
plt.savefig('./fig/sbucbcutoff-1.pdf', format='pdf',bbox_inches='tight', dpi=800)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import gridspec

fig = plt.figure(1,figsize=(10.2,3.7)) 
spec = gridspec.GridSpec(ncols=2, nrows=1,
                         width_ratios=[3.2, 1])

ax0 = fig.add_subplot(spec[0])


x = np.arange(0,10)

total_width, n = 0.5, 1
width = total_width / n
x = x - (total_width - width) / 1


plt.bar(x, pos_skip_rate_10[:10], width=width, color = "cornflowerblue", alpha=0.7)
plt.xticks(np.arange(0,10), [str(i*10+1)+"-"+str((i+1)*10) for i in range(0,9)] + ["  91-100"],size='small',fontsize=15)
plt.yticks(size='small',fontsize=15)
plt.ylim(0.07,0.13)
# plt.yticks(np.arange(0.09,0.13,0.01))
plt.ylabel("Percentage of User's Skip Events",fontsize=16)
plt.xlabel("Position in Session",fontsize=16)


fig.subplots_adjust(wspace=2.0)


ax1 = fig.add_subplot(spec[1])
SBUCB = [0.785975,0.784625,0.7833875,0.7826625,0.78225, 0.780875]
SBUCB.reverse()
label = ["2", "4", "6", "8", "10", "∞"]
label.reverse()

x = np.arange(0,6)

plt.barh(x, SBUCB, height=0.45, color='pink', alpha=0.9)
plt.yticks(np.arange(0,6),label ,size='small',fontsize=15)
plt.xticks(size='small',fontsize=15)
plt.xlim(0.779,0.787)
# plt.yticks(np.arange(0.09,0.13,0.01))
plt.xlabel("Online Average Reward",fontsize=16)
plt.ylabel("#  of  Cutoff",fontsize=16)

plt.tight_layout() #去除pdf周围白边
plt.savefig('./fig/introduction_analysis.pdf', format='pdf',bbox_inches='tight', dpi=800)
plt.show()

# %%
x = [2,4,6,8,10]
# ar = [0.883475,0.8860625,0.8922875,0.8954375,0.8940375]
ar=[0.8693625,
0.87815,
0.8811375,
0.8897875,
0.886525]
cdb = [0.8704]*5
plt.figure(1,figsize=(3,2.5)) 

plt.plot(x, cdb, color="r", linestyle="-", marker="None", linewidth=1, label="CDB")
plt.plot(x, ar, color="b", linestyle="-", marker="None", linewidth=1, label="NDB")

plt.grid(linestyle=":")  # 设置背景网格线为虚线
ax = plt.gca()

# # 设置ax区域背景颜色
# ax.patch.set_facecolor("gray")
plt.yticks(fontsize=14)
plt.xticks([2,4,6,8,10], [2,4,6,8,10],fontsize=14)

# # 设置ax区域背景颜色透明度
# ax.patch.set_alpha(0.2)
plt.xlabel("K",fontsize=15)
plt.ylabel("OnlineAverageReward@800",fontsize=15)
plt.legend(loc='center right')
# plt.title("(a)")

plt.tight_layout() #去除pdf周围白边
plt.savefig('./fig/numofduels.pdf', format='pdf',bbox_inches='tight', dpi=800)
plt.show()

# %%
x = np.arange(3)
ar = [0.895,0.899575,0.904075]
plt.figure(1,figsize=(3,2.5)) 
total_width, n = 0.8, 2
width = total_width / n
x = x - (total_width - width) / 1

plt.bar(x, ar, width=width, label='Train')

plt.legend(loc='best')

plt.yticks(fontsize=14)
plt.xticks(x, ["NDB w/o Kernal","NDB w/o modify", "NDB"],fontsize=14)
plt.ylim(0.87,0.91)

plt.xlabel("K",fontsize=15)
plt.ylabel("OnlineAverageReward@800",fontsize=15)
plt.legend(loc='center right')
# plt.title("(a)")

plt.tight_layout() #去除pdf周围白边
# plt.savefig('./fig/numofduels.pdf', format='pdf',bbox_inches='tight', dpi=800)
plt.show()

# %%
x = np.arange(1,11)

plt.figure(1,figsize=(6.5,3)) 

cdb_mean = np.array([0.7892]*10)
cdb_std = np.array([0.0040]*10)

plt.plot(x, cdb_mean, color="b", linestyle="-", marker="None", linewidth=1, label="CDB")
plt.fill_between(x,cdb_mean-cdb_std,cdb_mean+cdb_std,color='r',alpha=0.1)

# EXP3_mean = np.array([0.7889])
# EXP3_std = np.array([0.000586]*10)

ndb_mean = np.array([0.793365 , 0.79592  , 0.8002875, 0.8002475, 0.804355 , 0.803675 ,
       0.8168625, 0.81754  , 0.8225925, 0.8247925])
ndb_std = np.array([0.0155043 , 0.01237128, 0.00892771, 0.01468288, 0.01230001,
       0.00344033, 0.00627657, 0.01132342, 0.00660108, 0.0082428 ])

plt.plot(x, ndb_mean, color="r", linestyle="-", marker="None", linewidth=1, label="NDB")
plt.fill_between(x,ndb_mean-ndb_std,ndb_mean+ndb_std,color='b',alpha=0.1)


plt.yticks(fontsize=16)
plt.xticks(x,x,fontsize=16)


plt.grid(linestyle=":")  # 设置背景网格线为虚线
ax = plt.gca()

# 设置ax区域背景颜色
ax.patch.set_facecolor("gray")

# 设置ax区域背景颜色透明度
ax.patch.set_alpha(0.2)
plt.xlabel("Number of Dueling Models $K$",fontsize=17)
plt.ylabel("Online Average Reward",fontsize=17)
plt.legend(loc='upper left')
# plt.title("(a)")

plt.tight_layout() #去除pdf周围白边
plt.savefig('./fig/numofduels.pdf', format='pdf',bbox_inches='tight', dpi=800)
plt.show()

# %%
(0.8926575 - 0.8695625)/0.8695625
# Out:
# 0.026559332997915592
